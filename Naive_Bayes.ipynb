# %%
import pandas as pd
import numpy as np
import re

# %%
# data = None
# with open('data/digitdata/trainingimages', 'r') as file:
#     data = file.readlines()
#     data = re.sub(r'\n+', '\n',data)

lines = open('data/digitdata/trainingimages').read().splitlines()

# %%
# data = re.sub(r'\t\t\t', 'dfsdf',lines)
data = re.sub(r'\n+', '\n',lines)

# %%
lines
# Out:
# ['                            ',
#  '                            ',
#  '                            ',
#  '                            ',
#  '                            ',
#  '                +++++##+    ',
#  '        +++++######+###+    ',
#  '       +##########+++++     ',
#  '        #######+##          ',
#  '        +++###  ++          ',
#  '           +#+              ',
#  '           +#+              ',
#  '            +#+             ',
#  '            +##++           ',
#  '             +###++         ',
#  '              ++##++        ',
#  '                +##+        ',
#  '                 ###+       ',
#  '              +++###        ',
#  '            ++#####+        ',
#  '          ++######+         ',
#  '        ++######+           ',
#  '       +######+             ',
#  '    ++######+               ',
#  '    +####++                 ',
#  '                            ',
#  '                            ',
#  '                            ',
# ...

# %%
digits = []
ptr1 = 0
ptr2 = 0
print(len(lines)-1)
while ptr2 != len(lines):
    if '+' in lines[ptr2] or '#' in lines[ptr2]:
        new_l = []
        ptr1 = ptr2
        for i in range(ptr2, len(lines)-1):
            if '+' in lines[ptr2] or '#' in lines[ptr2]:
                new_l.append(lines[ptr2])
                ptr1 = i
            else:
                break
        ptr2 = ptr1
        digits.append(new_l)
    else:
        ptr2 += 1
    
digits[0]
# Out:
# 139999
# ['                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
#  '                +++++##+    ',
# ...

# %%
df = pd.read_csv('data/digitdata/trainingimages', skip_blank_lines=True, header=None, names=["A"])

# %%
df.iloc[1]
# Out:
# A            +++++######+###+
# Name: 1, dtype: object
